# %% [markdown]
# # Welcome to Jupyter!

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.6.2-cp36-cp36m-manylinux2010_x86_64.whl (458.3 MB)
#      |████████████████████████████████| 458.3 MB 33 kB/s
# Requirement already satisfied: wheel~=0.35 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from tensorflow) (0.37.0)
# Collecting keras<2.7,>=2.6.0
#   Downloading keras-2.6.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 49.8 MB/s
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Collecting typing-extensions~=3.7.4
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting tensorflow-estimator<2.7,>=2.6.0
#   Downloading tensorflow_estimator-2.6.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 52.7 MB/s
# Collecting termcolor~=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gast==0.4.0
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting tensorboard<2.7,>=2.6.0
#   Downloading tensorboard-2.6.0-py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 45.6 MB/s
# Collecting opt-einsum~=3.3.0
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 11.5 MB/s
# Collecting grpcio<2.0,>=1.37.0
#   Downloading grpcio-1.43.0-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#      |████████████████████████████████| 4.1 MB 55.2 MB/s
# Collecting astunparse~=1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy~=1.19.2 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from tensorflow) (1.19.5)
# Collecting keras-preprocessing~=1.1.2
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 4.7 MB/s
# Collecting clang~=5.0
#   Downloading clang-5.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Collecting google-pasta~=0.2
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 15.9 MB/s
# Collecting six~=1.15.0
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.19.1-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 56.3 MB/s
# Collecting absl-py~=0.10
#   Downloading absl_py-0.15.0-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 50.3 MB/s
# Collecting h5py~=3.1.0
#   Downloading h5py-3.1.0-cp36-cp36m-manylinux1_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 48.6 MB/s
# Collecting cached-property
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
#      |████████████████████████████████| 152 kB 46.9 MB/s
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
#      |████████████████████████████████| 781 kB 45.3 MB/s
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.6-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 18.6 MB/s
# Requirement already satisfied: requests<3,>=2.21.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (2.26.0)
# Collecting werkzeug>=0.11.15
#   Downloading Werkzeug-2.0.2-py3-none-any.whl (288 kB)
#      |████████████████████████████████| 288 kB 52.0 MB/s
# Requirement already satisfied: setuptools>=41.0.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (58.0.4)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 39.5 MB/s
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 51.6 MB/s
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow) (4.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (2.0.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (3.1)
# Requirement already satisfied: dataclasses in /srv/conda/envs/notebook/lib/python3.6/site-packages (from werkzeug>=0.11.15->tensorboard<2.7,>=2.6.0->tensorflow) (0.8)
# Requirement already satisfied: zipp>=0.5 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow) (3.6.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 3.6 MB/s
# Requirement already satisfied: oauthlib>=3.0.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow) (3.1.1)
# Building wheels for collected packages: clang, termcolor, wrapt
#   Building wheel for clang (setup.py) ... done
#   Created wheel for clang: filename=clang-5.0-py3-none-any.whl size=30692 sha256=52e333866642284a586b4e32ee0846b294f029d9ce65c5649978b94d0ec71737
#   Stored in directory: /home/jovyan/.cache/pip/wheels/22/4c/94/0583f60c9c5b6024ed64f290cb2d43b06bb4f75577dc3c93a7
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4847 sha256=8bec5b73bbb4b9b83288954e461632b0b72a04db11484bbdf4a8b48364b4b40e
#   Stored in directory: /home/jovyan/.cache/pip/wheels/93/2a/eb/e58dbcbc963549ee4f065ff80a59f274cc7210b6eab962acdc
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=69668 sha256=3ad81c80c16a79cdbb9cb8074257b8649fc5f0534c7b77fdab78fa5cfa0fc369
#   Stored in directory: /home/jovyan/.cache/pip/wheels/32/42/7f/23cae9ff6ef66798d00dc5d659088e57dbba01566f6c60db63
# Successfully built clang termcolor wrapt
# Installing collected packages: pyasn1, typing-extensions, six, rsa, pyasn1-modules, cachetools, requests-oauthlib, google-auth, werkzeug, tensorboard-plugin-wit, tensorboard-data-server, protobuf, markdown, grpcio, google-auth-oauthlib, cached-property, absl-py, wrapt, termcolor, tensorflow-estimator, tensorboard, opt-einsum, keras-preprocessing, keras, h5py, google-pasta, gast, flatbuffers, clang, astunparse, tensorflow
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.0.0
#     Uninstalling typing-extensions-4.0.0:
#       Successfully uninstalled typing-extensions-4.0.0
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
# Successfully installed absl-py-0.15.0 astunparse-1.6.3 cached-property-1.5.2 cachetools-4.2.4 clang-5.0 flatbuffers-1.12 gast-0.4.0 google-auth-1.35.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.43.0 h5py-3.1.0 keras-2.6.0 keras-preprocessing-1.1.2 markdown-3.3.6 opt-einsum-3.3.0 protobuf-3.19.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.0 rsa-4.8 six-1.15.0 tensorboard-2.6.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.6.2 tensorflow-estimator-2.6.0 termcolor-1.1.0 typing-extensions-3.7.4.3 werkzeug-2.0.2 wrapt-1.12.1
# Note: you may need to restart the kernel to use updated packages.

# %%
#Step 1: import the necessary modules
import tensorflow as tf
from tensorflow import keras

# %%
#Step 2: Import the MNIST Fashion Dataset
fashiondata=tf.keras.datasets.mnist

# %%
#Step 3: split the dataset into training and test dataset

(x_train, y_train), (x_test, y_test)= fashiondata.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_train, x_test=x_train/255,x_test/255

# %%
#Step 4: Build the neural network
model=tf.keras.models.Sequential([tf.keras.layers.Flatten(input_shape=(28,28)),
                                 tf.keras.layers.Dense(128, activation='relu'),
                                 tf.keras.layers.Dropout(0.2),
                                 tf.keras.layers.Dense(10, activation='softmax')])

# %%
#Step 5: Compile the model using adam ompitmizer

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
#Step 6: Train the model

model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2991 - accuracy: 0.9142
# Epoch 2/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1435 - accuracy: 0.9576
# Epoch 3/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1084 - accuracy: 0.9672
# Epoch 4/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0872 - accuracy: 0.9731
# Epoch 5/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0754 - accuracy: 0.9764

# %%
#Step 7: Evalutate the models

model.evaluate(x_test, y_test )
# Out:
# 313/313 [==============================] - 0s 879us/step - loss: 0.0748 - accuracy: 0.9757
# [0.07480977475643158, 0.9757000207901001]
